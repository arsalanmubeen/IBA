# %% [markdown]
# <a href="https://colab.research.google.com/github/arsalanmubeen/IBA/blob/main/Assignment_1_Prob_Distr(23394).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import norm,stats
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Normal Distribution
#
#
#
#
# Q1: Calculate the filled-up area under each normal/gaussian curve below:
# ![image.png](data:image/png;base64,...)

# %%
prob_1 = norm.cdf(0.75)
print(prob_1)


prob_2 = norm.cdf(-0.75)
print(prob_2)


cdf_upper_limit = norm.cdf(1.2)
cdf_lower_limit = norm.cdf(-0.6)
 
prob_3 = cdf_upper_limit - cdf_lower_limit
print(prob_3)


cdf_upper_limit = norm.cdf(1.6)
cdf_lower_limit = norm.cdf(-0.9)
 
prob_4 = cdf_upper_limit - cdf_lower_limit
print(prob_4)
# Out:
# 0.7733726476231317
# 0.2266273523768682
# 0.6106772120282182
# 0.7611405829536826

# %% [markdown]
# Q2: Assume that temperatures are distributed according to the standard normal distribution. Find the probability that a random temp measurement complies with the following requirements:
# *	less than −5.5∘
# *	less than 4.44
# *	greater than 29.99
# *	greater than −15.5
# *	between 15∘ and 40∘
# *	between −23.00∘ and −2.00∘
# *	greater than 0∘

# %%
prob_1 = norm.cdf(-5.5)
print("less than −5.5 =",prob_1)

prob_1 = norm.cdf(4.44)
print("less than 4.44 =",prob_1)

cdf_value = norm.cdf(29.99)
prob_3 = 1- cdf_value
print("greater than 29.99 = ",prob_3)

cdf_value = norm.cdf(-15.5)
prob_3 = 1- cdf_value
print("greater than −15.5 = ",prob_3)


cdf_upper_limit = norm.cdf(40)
cdf_lower_limit = norm.cdf(15)
 
prob_2 = cdf_upper_limit - cdf_lower_limit
print("between 15∘ and 40∘ = ",prob_2)

cdf_upper_limit = norm.cdf(-2.00)
cdf_lower_limit = norm.cdf(-23.00)
 
prob_2 = cdf_upper_limit - cdf_lower_limit
print("between −23.00∘ and −2.00∘ = ",prob_2)

cdf_value = norm.cdf(0)
prob_3 = 1- cdf_value
print("greater than 0 = ",prob_3)
# Out:
# less than −5.5 = 1.898956246588768e-08
# less than 4.44 = 0.9999955020561114
# greater than 29.99 =  0.0
# greater than −15.5 =  1.0
# between 15∘ and 40∘ =  0.0
# between −23.00∘ and −2.00∘ =  0.022750131948179195
# greater than 0 =  0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cdf_value = norm.ppf(0.9798)
print("z-score's area 0.9798  = ",cdf_value)

cdf_value = norm.ppf(0.2546)
print("z-score's area 0.2546  = ",cdf_value)

cdf_value = norm.ppf(0.2546)
print("z-score's area 0.2546  = ",cdf_value)

cdf_value = norm.ppf(0.9418)
print("z-score's area 0.9418  = ",cdf_value)
# Out:
# z-score's area 0.9798  =  2.0496356380817193
# z-score's area 0.2546  =  -0.6600838842403063
# z-score's area 0.2546  =  -0.6600838842403063
# z-score's area 0.9418  =  1.5700649575278007

# %% [markdown]
# Q4: Estimate the following probabilities:
# *	P(z>3.30)
# *	P(−0.43<z<1.54)
# *	P(z>−3.1)
# *	P(z<−4.5)

# %%
cdf_value = norm.cdf(3.30)
print("P(z>3.30) = ",cdf_value)


cdf_upper_limit = norm.cdf(1.54)
cdf_lower_limit = norm.cdf(-0.43)
 
prob_2 = cdf_upper_limit - cdf_lower_limit
print("P(−0.43<z<1.54) = ",prob_2)

cdf_value = norm.cdf(-3.1)
print("P(z>−3.1) = ",cdf_value)

cdf_value = norm.cdf(-4.5)
prob_3 = 1- cdf_value
print("P(z<−4.5) = ",prob_3)
# Out:
# P(z>3.30) =  0.9995165758576162
# P(−0.43<z<1.54) =  0.6046220026927305
# P(z>−3.1) =  0.0009676032132183563
# P(z<−4.5) =  0.9999966023268753

# %% [markdown]
# Q5: Estimate the value of m:
# *	P(z<m)=0.9664
# *	P(z<m)=0.3050
# *	P(z>m) =0.0078

# %%
cdf_value = norm.ppf(0.9664)
print("P(z<m)=0.9664  = ",cdf_value)

cdf_value = norm.ppf(0.3050)
print("P(z<m)=0.3050  = ",cdf_value)

cdf_value = norm.ppf(0.0078)
print("P(z>m)=0.0078  = ",cdf_value + 1)
# Out:
# P(z<m)=0.9664  =  1.8303340685028076
# P(z<m)=0.3050  =  -0.5100734569685949
# P(z>m)=0.0078  =  -1.4181417132227403

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(norm(100,15).ppf(0.6))
print(norm(100,15).ppf(0.8))
print(norm(100,15).ppf(0.99))
# Out:
# 103.80020654703699
# 112.62431850359371
# 134.8952181106126

# %% [markdown]
# Q7: The average salary for freshmen professors is PKR 50,000. Assume normal distribution with standard deviation 2140.
# *	What is the probability that a randomly selected first-year teacher makes between 15,000 and 35,000 each year?
# *	What is the probability that a randomly selected freshman prof has a salary less than 22,000?
# *	What is the probability that a randomly selected freshman prof has a salary at least 12,000?
# *	What is 90th percentile salary?

# %%
Z1 = (15000 - 50000) / 2140
Z2 = (35000 - 50000) / 2140

cdf_upper_limit = norm.cdf(Z2)
cdf_lower_limit = norm.cdf(Z1)
 
prob_2 = cdf_upper_limit - cdf_lower_limit
print("Q7.1,   Z1 = ",Z1,",Z2 = ",Z2," ,The probability is equal to  = ",prob_2)

Z = (22000 - 50000) / 2140
prob_2 = norm.cdf(Z)
print("Q7.2,   Z = ",Z," ,The probability is equal to  = ",prob_2)

Z = (12000 - 50000) / 2140
prob_2 = norm.cdf(Z)
print("Q7.3,   Z = ",Z," ,The probability is equal to  = ",1 - prob_2)

A = (2140 * (-norm.ppf(0.90))) + 50000
print("Q7.4,   90th percentile = ",A)
# Out:
# Q7.1,   Z1 =  -16.35514018691589 ,Z2 =  -7.009345794392523  ,The probability is equal to  =  1.197175112041309e-12
# Q7.2,   Z =  -13.08411214953271  ,The probability is equal to  =  2.029374580583214e-39
# Q7.3,   Z =  -17.757009345794394  ,The probability is equal to  =  1.0
# Q7.4,   90th percentile =  47257.47964973455

# %%
def Draw_the_graph(lower_limit,upper_limit,mu,sigma):
  z1 = ( lower_limit - mu ) / sigma
  z2 = ( upper_limit - mu ) / sigma

  x = np.arange(z1, z2, 0.001) # range of x in spec
  x_all = np.arange(-10, 10, 0.001) # entire range of x, both in and out of spec
  # mean = 0, stddev = 1, since Z-transform was calculated
  y = norm.pdf(x,0,1)
  y2 = norm.pdf(x_all,0,1)

  fig, ax = plt.subplots(figsize=(9,6))
  plt.style.use('fivethirtyeight')
  ax.plot(x_all,y2)

  ax.fill_between(x,y,0, alpha=0.3, color='b')
  ax.fill_between(x_all,y2,0, alpha=0.1)
  ax.set_xlim([-3,3])
  ax.set_xlabel('Draw the graph')
  ax.set_yticklabels([])

  plt.show()

# %% [markdown]
# # Confidence Interval
# Q1: Construct a 95% confidence interval for the mean height of male Pakistanis. Forty-nine male Pakistanis are surveyed. The sample mean is 71 inches. The sample standard deviation is 2.8 inches.
# *	State the CI interval
# *	Draw the graph
# *	Calculate the error bound
# *	What will happen to the level of confidence obtained if 2,000 male Pakistanis are surveyed instead of 49? Why?

# %%
mu = 71
sigma = 2.8

print( "State the CI interval = " ,norm.interval(0.95,mu,sigma),"\n\n")
lower_limit,upper_limit  = norm.interval(0.95,mu,sigma)

Draw_the_graph(lower_limit,upper_limit,mu,sigma)

EBM = upper_limit - mu
print ("\nEBM = " ,EBM)

print("\nThe confidence interval will decrease in size, because the sample size increased. Recall, when all factors remain unchanged, an increase in sample size decreases variability. Thus, we do not need as large an interval to capture the true population mean.")
# Out:
# State the CI interval =  (65.51210084328785, 76.48789915671215)
# EBM =  5.487899156712146
#
# The confidence interval will decrease in size, because the sample size increased. Recall, when all factors remain unchanged, an increase in sample size decreases variability. Thus, we do not need as large an interval to capture the true population mean.

# %% [markdown]
# Q2: We do a survey to estimate the time needed to complete one person’s tax forms. We randomly survey 1000 people. The mean is 33.8 hours with sd of 6.5 hours. Assume normality
# *	State the CI interval
# *	Draw the graph
# *	Calculate the error bound

# %%
x = 33.8
sigma = 6.5
n=1000
y = sigma/n**(1/2)
cdf_upper_limit = norm.cdf(x)
cdf_lower_limit = norm.cdf(y)
 
prob_2 = cdf_upper_limit - cdf_lower_limit

print( "State the CI interval = " ,norm.interval(prob_2,x,sigma),"\n\n")
lower_limit,upper_limit  = norm.interval(prob_2,x,sigma)

Draw_the_graph(lower_limit,upper_limit,x,sigma)

EBM = upper_limit - x
print ("\nEBM = " ,EBM)
# Out:
# State the CI interval =  (30.216549812299842, 37.38345018770015)
# EBM =  3.5834501877001514

# %% [markdown]
# Q3: The average height of children has a normal distribution with standard deviation of 3.4 inches. We are interested in estimating the mean height of children at school to within two inches with 93% confidence. How many children must you measure?

# %%
SD = 2.5
CL = 0.93
EBM = 2

a = 1 - CL
a2 = a / 2
Z= abs(norm.ppf(a2))

n = ((Z**2)*(SD**2)) / EBM**2
print(n)
# Out:
# 5.129719198061777

# %% [markdown]
# # Central Limit Theorem
# Q1: Model any problem from the agricultural domain in Python and demonstrate the central limit theorem (like dice roll and coin toss example).

# %% [markdown]
# Suppose we are sampling from Crop Yields with a finite mean and a finite standard-deviation(sigma). Then Mean and standard deviation of the sampling distribution of the sample mean can be given as:
#  mu*bar{X}=mu , sigma*bar{X}=sigma\sqrt{n}
# Where bar{X}  represents the sampling distribution of the sample mean of size n each, \mu  and \sigma  are the mean and standard deviation of the population respectively.
# The distribution of the sample tends towards the normal distribution as the sample size increases.

# %%
# number of sample
num = [1, 10, 50, 100] 
# list of sample means
means = [] 
 
# Generating 1, 10, 30, 100 random numbers from -40 to 40
# taking their mean and appending it to list means.
for j in num:
    # Generating seed so that we can get same result
    # every time the loop is run...
    np.random.seed(1)
    x = [np.mean(
        np.random.randint(
            -40, 40, j)) for _i in range(1000)]
    means.append(x)
k = 0
 
# plotting all the means in one figure
fig, ax = plt.subplots(2, 2, figsize =(8, 8))
for i in range(0, 2):
    for j in range(0, 2):
        # Histogram for each x stored in means
        ax[i, j].hist(means[k], 10, density = True)
        ax[i, j].set_title(label = num[k])
        k = k + 1
plt.show()

# %% [markdown]
# # Other Probability Distributions
# Q1: Create a notebook which clearly demonstrates the basic concepts and hands-on of Logistic, Log-Logistic, Logit-Normal distributions along with the logit function. You need to add comments in your own words. (Similarly, to how I have done in the notebook)

# %% [markdown]
# # scipy.stats.logistic

# %%
from scipy.stats import logistic
fig, ax = plt.subplots(1, 1)

#Calculate the first four moments:

mean, var, skew, kurt = logistic.stats(moments='mvsk')

#Display the probability density function (pdf):
x = np.linspace(logistic.ppf(0.01),logistic.ppf(0.99), 100)
ax.plot(x, logistic.pdf(x),'r-', lw=5, alpha=0.6, label='logistic pdf')

#Alternatively, the distribution object can be called (as a function) to fix the shape, location and scale parameters. This returns a “frozen” RV object holding the given parameters fixed.
#Freeze the distribution and display the frozen pdf:

rv = logistic()
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

#Check accuracy of cdf and ppf:

vals = logistic.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], logistic.cdf(vals))

#Generate random numbers:

r = logistic.rvs(size=1000)

#And compare the histogram

ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # scipy.stats.fisk
#
# A Fisk continuous random variable.
#
# The Fisk distribution is also known as the log-logistic distribution.

# %%
from scipy.stats import fisk
fig, ax = plt.subplots(1, 1)

#Calculate the first four moments

c = 3.09
mean, var, skew, kurt = fisk.stats(c, moments='mvsk')

#Display the probability density function (pdf):

x = np.linspace(fisk.ppf(0.01, c),fisk.ppf(0.99, c), 100)
ax.plot(x, fisk.pdf(x, c),'r-', lw=5, alpha=0.6, label='fisk pdf')

#Alternatively, the distribution object can be called (as a function) to fix the shape, location and scale parameters. This returns a “frozen” RV object holding the given parameters fixed.
#Freeze the distribution and display the frozen pdf:

rv = fisk(c)
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

#Check accuracy of cdf and ppf:

vals = fisk.ppf([0.001, 0.5, 0.999], c)
np.allclose([0.001, 0.5, 0.999], fisk.cdf(vals, c))

#Generate random numbers:

r = fisk.rvs(c, size=1000)

#And compare the histogram:

ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # Logit-Normal distributions along with the logit function

# %%
from scipy.special import logit
from scipy.stats import  rv_continuous

# example pass scale and loc when creating an instance of LogitNormal and store the values as class attributes:
class LogitNormal(rv_continuous):
    def __init__(self, scale=1, loc=0):
        super().__init__(self)
        self.scale = scale
        self.loc = loc

    def _pdf(self, x):
        return norm.pdf(logit(x), loc=self.loc, scale=self.scale)/(x*(1-x))


fig, ax = plt.subplots()
values = np.linspace(10e-10, 1-10e-10, 1000)
sigma, mu = 1.78, 0
ax.plot(
    values, LogitNormal(scale=sigma, loc=mu).pdf(values), label='subclassed'
)
ax.legend()
fig.show()
